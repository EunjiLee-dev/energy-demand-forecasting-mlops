# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("default")

# %%
df = pd.read_csv("../data/processed/final_dataset.csv")

df["datetime"] = pd.to_datetime(df["datetime"])
df = df.sort_values("datetime")

df.head()
# Out:
#              datetime   demand  temperature  humidity  precipitation  \
# 0 2023-01-08 00:00:00  6868.64          3.9        95            0.0
# 1 2023-01-08 01:00:00  7227.70          0.8        95            0.0
# 2 2023-01-08 02:00:00  7285.53          1.7        89            0.0
# 3 2023-01-08 03:00:00  7348.04          2.3        87            0.0
# 4 2023-01-08 04:00:00  7186.26          4.3        76            0.0
#
#    wind_speed  cloud  shortwave  apparent_temp  hour  dayofweek  month  \
# 0         2.2    100        0.0            2.0     0          6      1
# 1         7.2      8        0.0           -2.4     1          6      1
# 2         8.4     43        0.0           -1.6     2          6      1
# 3         6.5     99        0.0           -0.7     3          6      1
# 4         6.6    100        0.0            1.3     4          6      1
#
#      lag_1   lag_24  lag_168  rolling_mean_24  rolling_std_24
# 0  6991.66  7629.36  7373.01      7280.571250      281.889190
# 1  6868.64  7823.83  7464.26      7255.732500      257.113833
# 2  7227.70  6925.29  6896.76      7270.742500      247.312641
# 3  7285.53  6761.84  7145.96      7295.167500      222.577459
# 4  7348.04  7184.45  7148.45      7295.242917      222.538617

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26134 entries, 0 to 26133
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   datetime         26134 non-null  datetime64[us]
#  1   demand           26134 non-null  float64
#  2   temperature      26134 non-null  float64
#  3   humidity         26134 non-null  int64
#  4   precipitation    26134 non-null  float64
#  5   wind_speed       26134 non-null  float64
#  6   cloud            26134 non-null  int64
#  7   shortwave        26134 non-null  float64
#  8   apparent_temp    26134 non-null  float64
#  9   hour             26134 non-null  int64
#  10  dayofweek        26134 non-null  int64
#  11  month            26134 non-null  int64
#  12  lag_1            26134 non-null  float64
#  13  lag_24           26134 non-null  float64
#  14  lag_168          26134 non-null  float64
#  15  rolling_mean_24  26134 non-null  float64
#  16  rolling_std_24   26134 non-null  float64
# dtypes: datetime64[us](1), float64(11), int64(5)
# memory usage: 3.4 MB

# %%
df["demand"].describe()
# Out:
# count    26134.000000
# mean      6958.538167
# std       1079.099176
# min       2373.540000
# 25%       6253.490000
# 50%       6963.850000
# 75%       7666.787500
# max      15866.320000
# Name: demand, dtype: float64

# %%
plt.figure(figsize=(10,4))
sns.histplot(df["demand"], bins=50)
plt.title("Demand Distribution")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(df["datetime"], df["demand"])
plt.title("Demand Over Time")
plt.show()

# %%
df["hour"] = df["datetime"].dt.hour

plt.figure(figsize=(10,5))
sns.boxplot(x="hour", y="demand", data=df)
plt.title("Demand by Hour")
plt.show()

# %%
df["dayofweek"] = df["datetime"].dt.dayofweek

plt.figure(figsize=(10,5))
sns.boxplot(x="dayofweek", y="demand", data=df)
plt.title("Demand by Day of Week")
plt.show()
